# %% [markdown]
# ### Sea

# %%
import seaborn as sns
sns.set(style="whitegrid")
tips=sns.load_dataset("tips")
sns.barplot(x="day",y="total_bill",data=tips)
# Out:
# C:\Users\prati\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
import seaborn as sns
sns.set(style="whitegrid")
tips=sns.load_dataset("tips")
numeric_data=tips.select_dtypes(include='number')
sns.heatmap(numeric_data.corr(),annot=True,cmap="coolwarm")
# Out:
# <Axes: >

# %%
numeric_data.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

data={
    "Solar":[1200,1500,1300],
    "wind":[3400,3600,3200],
    "Hydropower":[2900,3100,2800],
    "Biomass":[2500,2700,2400]
}

df=pd.DataFrame(data)
sns.pairplot(df)
plt.show()
# Out:
# C:\Users\prati\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\prati\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\prati\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\prati\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
correlation_matrix=df.corr()
sns.heatmap(correlation_matrix,annot=True,cmap='coolwarm',linewidths=0.5)
plt.title('correlation Between Energy Source')
plt.show()

# %%
sns.boxplot(data=df)
plt.title('Distribution of Energy Consumption by Soure')
plt.show()

# %%
correlation_matrix
# Out:
#                Solar      wind  Hydropower   Biomass
# Solar       1.000000  0.654654    0.785714  0.785714
# wind        0.654654  1.000000    0.981981  0.981981
# Hydropower  0.785714  0.981981    1.000000  1.000000
# Biomass     0.785714  0.981981    1.000000  1.000000

# %% [markdown]
# ### ViolinPLon of Energy Consumption Distribution

# %% [markdown]
# sns.violinplot(data=df)
# plt.title('Violin Plot of Energy Consumption Distribution')
# plt.show()

# %% [markdown]
# ### Regration Plot

# %%
energy_values=[100,200,300,400,500]
carbon_emissions=[10,20,30,40,50]

df_reg=pd.DataFrame({
    'Energy Consumption':energy_values,
    'Carbon Emissions': carbon_emissions
})

sns.regplot(x='Energy Consumption',y='Carbon Emissions',data=df_reg)
plt.title('Energy Consumption vs Carbon Emissions')
plt.xlabel('Energy Consumption')
plt.ylabel('Carbon Emissions')
plt.show()

# %% [markdown]
# ### Facet Grid

# %%
months = ['January', 'February', 'March', 'April', 'May', 'June']
df_facet = pd.DataFrame({
    'Month': months * 3,  # 6 months repeated 3 times
    'Energy Consumption': [1200, 1300, 1100, 1500, 1400, 1600] * 3,
    'Region': ['North'] * 6 + ['South'] * 6 + ['East'] * 6  # 6 entries per region
})
g.sns.FacetGrid(df_facet,col='Region',hue='Region',height=4,aspect=1)
g.map(sns.lineplot,'Month','Energy Consumption')
plt.subplots_adjust(top=0.85)
g.fig.suptile('Energy Consumption Over Time By Region')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 7
#       1 months = ['January', 'February', 'March', 'April', 'May', 'June']
#       2 df_facet = pd.DataFrame({
#       3     'Month': months * 3,  # 6 months repeated 3 times
#       4     'Energy Consumption': [1200, 1300, 1100, 1500, 1400, 1600] * 3,
#       5     'Region': ['North'] * 6 + ['South'] * 6 + ['East'] * 6  # 6 entries per region
#       6 })
# ----> 7 g.sns.FacetGrid(df_facet,col='Region',hue='Region',height=4,aspect=1)
#       8 g.map(sns.lineplot,'Month','Energy Consumption')
#       9 plt.subplots_adjust(top=0.85)
#
# AttributeError: 'FacetGrid' object has no attribute 'sns'
